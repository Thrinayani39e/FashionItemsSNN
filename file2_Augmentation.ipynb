# %%
import numpy as np
from tensorflow.keras.datasets import fashion_mnist
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# Load the Fashion MNIST dataset
(x_train, y_train), (x_test, y_test) = fashion_mnist.load_data()

# Normalize pixel values to [0, 1]
x_train, x_test = x_train / 255.0, x_test / 255.0

# Reshape the input data if needed
# x_train = x_train.reshape(-1, 28, 28, 1)  # If your model expects this shape

# One-hot encode the target labels
y_train = to_categorical(y_train, num_classes=10)
y_test = to_categorical(y_test, num_classes=10)

# Data augmentation
datagen = ImageDataGenerator(
    rotation_range=10,      # Randomly rotate images by up to 10 degrees
    width_shift_range=0.1,  # Randomly shift images horizontally by up to 10% of the width
    height_shift_range=0.1, # Randomly shift images vertically by up to 10% of the height
    horizontal_flip=True,   # Randomly flip images horizontally
    zoom_range=0.1          # Randomly zoom images by up to 10%
)

# Fit the data generator on the training data
datagen.fit(x_train.reshape(-1, 28, 28, 1))

# Create a generator for augmented data
augmented_data_gen = datagen.flow(
    x_train.reshape(-1, 28, 28, 1),
    y_train,
    batch_size=64,
    shuffle=True
)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 29515/29515 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26421880/26421880 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 5148/5148 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4422102/4422102 [==============================] - 0s 0us/step

# %%
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.optimizers import Adamax

# Define the SCNN model
model = models.Sequential()

# Convolutional Layer 1
model.add(layers.Conv2D(32, (3, 3), activation='relu', input_shape=(28, 28, 1), padding='same'))
model.add(layers.MaxPooling2D((2, 2), strides=(2, 2)))

# Convolutional Layer 2
model.add(layers.Conv2D(128, (3, 3), activation='relu', padding='same'))
model.add(layers.MaxPooling2D((2, 2), strides=(2, 2)))

# Convolutional Layer 3
model.add(layers.Conv2D(256, (3, 3), activation='relu', padding='same'))
model.add(layers.MaxPooling2D((2, 2), strides=(2, 2)))

# Flatten layer
model.add(layers.Flatten())

# Dense layer
model.add(layers.Dense(512, activation='relu'))

# Output layer
model.add(layers.Dense(10, activation='softmax'))

# Compile the model
optimizer = Adamax(learning_rate=1e-3)
model.compile(optimizer=optimizer,
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# Print model summary
model.summary()

# Train the model
batch_size = 64
epochs = 10

history = model.fit(x_train.reshape(-1, 28, 28, 1), y_train,
                    batch_size=batch_size,
                    epochs=epochs,
                    validation_data=(x_test.reshape(-1, 28, 28, 1), y_test))

# Evaluate the model on test data
test_loss, test_accuracy = model.evaluate(x_test.reshape(-1, 28, 28, 1), y_test)
print(f'Test accuracy: {test_accuracy*100:.2f}%')
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_9 (Conv2D)           (None, 28, 28, 32)        320
#
#  max_pooling2d_9 (MaxPoolin  (None, 14, 14, 32)        0
#  g2D)
#
#  conv2d_10 (Conv2D)          (None, 14, 14, 128)       36992
#
#  max_pooling2d_10 (MaxPooli  (None, 7, 7, 128)         0
#  ng2D)
#
#  conv2d_11 (Conv2D)          (None, 7, 7, 256)         295168
#
#  max_pooling2d_11 (MaxPooli  (None, 3, 3, 256)         0
#  ng2D)
#
#  flatten_3 (Flatten)         (None, 2304)              0
#
#  dense_6 (Dense)             (None, 512)               1180160
#
#  dense_7 (Dense)             (None, 10)                5130
#
# =================================================================
# Total params: 1517770 (5.79 MB)
# Trainable params: 1517770 (5.79 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/10
# 938/938 [==============================] - 242s 257ms/step - loss: 0.4894 - accuracy: 0.8219 - val_loss: 0.3751 - val_accuracy: 0.8659
# Epoch 2/10
# 938/938 [==============================] - 236s 251ms/step - loss: 0.3175 - accuracy: 0.8846 - val_loss: 0.3086 - val_accuracy: 0.8899
# Epoch 3/10
# 938/938 [==============================] - 237s 252ms/step - loss: 0.2676 - accuracy: 0.9029 - val_loss: 0.2805 - val_accuracy: 0.8992
# Epoch 4/10
# 938/938 [==============================] - 236s 251ms/step - loss: 0.2333 - accuracy: 0.9150 - val_loss: 0.2527 - val_accuracy: 0.9057
# Epoch 5/10
# 938/938 [==============================] - 235s 251ms/step - loss: 0.2084 - accuracy: 0.9234 - val_loss: 0.2637 - val_accuracy: 0.9071
# Epoch 6/10
# 938/938 [==============================] - 235s 251ms/step - loss: 0.1881 - accuracy: 0.9302 - val_loss: 0.2307 - val_accuracy: 0.9177
# Epoch 7/10
# 938/938 [==============================] - 236s 252ms/step - loss: 0.1684 - accuracy: 0.9376 - val_loss: 0.2268 - val_accuracy: 0.9202
# Epoch 8/10
# 938/938 [==============================] - 236s 251ms/step - loss: 0.1519 - accuracy: 0.9441 - val_loss: 0.2316 - val_accuracy: 0.9163
# Epoch 9/10
# 938/938 [==============================] - 235s 251ms/step - loss: 0.1368 - accuracy: 0.9497 - val_loss: 0.2239 - val_accuracy: 0.9217
# Epoch 10/10
# 938/938 [==============================] - 236s 252ms/step - loss: 0.1194 - accuracy: 0.9573 - val_loss: 0.2326 - val_accuracy: 0.9252
# 313/313 [==============================] - 11s 34ms/step - loss: 0.2326 - accuracy: 0.9252
# Test accuracy: 92.52%
